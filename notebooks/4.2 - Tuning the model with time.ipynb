# %% [markdown]
# ## Tuning the model with Time

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras import metrics
import numpy as np

# %%
 # Load back from the pickle file.
import pickle

songs = pickle.load( open( "../songs.p", "rb" ) )

# %%
songs[:1]
# Out:
# [[{'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': 1.0},
#   {'relative_offset': 0.5, 'interval': -27.0, 'duration': 0.5},
#   {'relative_offset': 0.5, 'interval': 29.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.75, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': 1.0},
#   {'relative_offset': 0.5, 'interval': -27.0, 'duration': 0.5},
#   {'relative_offset': 0.5, 'interval': 29.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.75, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 1.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': 1.0},
#   {'relative_offset': 0.5, 'interval': -27.0, 'duration': 0.5},
#   {'relative_offset': 0.5, 'interval': 29.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.75, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': 1.0},
#   {'relative_offset': 0.5, 'interval': -27.0, 'duration': 0.5},
#   {'relative_offset': 0.5, 'interval': 29.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.75, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)}]]

# %%
import fractions

# %%
duration_to_number = {}
number_to_duration  = {}

count=0
duration = 0
while duration <= 20:
    number_to_duration[count] = duration
    duration_to_number[duration] = count
    count+=1
    duration+=0.25

duration = 0
while duration <= 20:
    if not duration in duration_to_number:
        number_to_duration[count] = duration
        duration_to_number[duration] = count
        count+=1
    duration+=fractions.Fraction(1,3)

# %%
interval_to_number = {}
number_to_interval = {}

for i in range(0,100):
    interval_to_number[i] = i
    interval_to_number[-i] = 100 + i
    number_to_interval[i] = i
    number_to_interval[100+i] = -i

# %%
train_set = [ \
    [\
        [
         duration_to_number[round(element['relative_offset']*4)/4] if (round(element['relative_offset']*4)/4 in duration_to_number) else 1, 
         interval_to_number[element['interval']], 
         duration_to_number[element['duration']]
        ] \
    for element in song]\
for song in songs]

# %%
songs[96]
# Out:
# [{'relative_offset': 2.0, 'interval': 24.0, 'duration': 0.5},
#  {'relative_offset': 1.0, 'interval': -2.0, 'duration': 3.5},
#  {'relative_offset': 5.0, 'interval': -2.0, 'duration': 1.75},
#  {'relative_offset': 2.0, 'interval': -1.0, 'duration': 0.25}]

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = np.array(sequences)[i:end_ix, :], np.array(sequences)[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X, y = [], []
for i in range(len(train_set)):
    X_temp, y_temp = split_sequences(train_set[i], 10)
      
    if (len(X_temp) > 0 and len(y_temp) > 0):
        X = X_temp if len(X)==0 else np.concatenate([X,X_temp])
        y = y_temp if len(y)==0 else np.concatenate([y,y_temp])
# Out:
# 0
# (118, 10, 3)
# (118, 3)
# 1
# (703, 10, 3)
# (703, 3)
# 2
# (108, 10, 3)
# (108, 3)
# 3
# (41, 10, 3)
# (41, 3)
# 4
# (76, 10, 3)
# (76, 3)
# 5
# (26, 10, 3)
# (26, 3)
# 6
# (127, 10, 3)
# (127, 3)
# 7
# (76, 10, 3)
# (76, 3)
# 8
# (128, 10, 3)
# (128, 3)
# 9
# (189, 10, 3)
# (189, 3)
# 10
# (161, 10, 3)
# (161, 3)
# 11
# (124, 10, 3)
# (124, 3)
# 12
# (160, 10, 3)
# (160, 3)
# 13
# (28, 10, 3)
# (28, 3)
# 14
# (58, 10, 3)
# (58, 3)
# 15
# (78, 10, 3)
# (78, 3)
# 16
# (116, 10, 3)
# (116, 3)
# 17
# (153, 10, 3)
# (153, 3)
# 18
# (130, 3)
# 86
# (279, 10, 3)
# (279, 3)
# 87
# (915, 10, 3)
# (915, 3)
# 88
# (117, 10, 3)
# (117, 3)
# 89
# (111, 10, 3)
# (111, 3)
# 90
# (510, 10, 3)
# (510, 3)
# 91
# (160, 10, 3)
# (160, 3)
# 92
# (94, 10, 3)
# (94, 3)
# 93
# (64, 10, 3)
# (64, 3)
# 94
# (60, 10, 3)
# (60, 3)
# 95
# (14, 10, 3)
# (14, 3)
# 96
# (0,)
# (0,)
# 97
# (4, 10, 3)
# (4, 3)
# 98
# (23, 10, 3)
# (23, 3)
# 99
# (16, 10, 3)
# (16, 3)
# 100
# (11, 10, 3)
# (11, 3)
# 101
# (11, 10, 3)
# (11, 3)
# 102
# (0,)
# (0,)
# 103
# (0,)
# (0,)
# 104
# (0,)
# (0,)
# 105
# (1, 10, 3)
# (1, 3)
# 106
# (0,)
# (0,)
# 107
# (7, 10, 3)
# (7, 3)
# 108
# (5, 10, 3)
# (5, 3)
# 109
# (0,)
# (0,)
# 110
# (0,)
# (0,)
# 111
# (4, 10, 3)
# (4, 3)
# 112
# (0,)
# (0,)
# 113
# (8, 10, 3)
# (8, 3)
# 114
# (22, 10, 3)
# (22, 3)
# 115
# (1, 10, 3)
# (1, 3)
# 116
# (0,)
# (0,)
# 117
# (0,)
# (0,)
# 118
# (17, 10, 3)
# (17, 3)
# 119
# (0,)
# (0,)
# 120
# (5, 10, 3)
# (5, 3)
# 121
# (0,)
# (0,)
# 122
# (10, 10, 3)
# (10, 3)
# 123
# (29, 10, 3)
# (29, 3)
# 124
# (0,)
# (0,)
# 125
# (0,)
# (0,)
# 126
# (5, 10, 3)
# (5, 3)
# 127
# (0,)
# (0,)
# 128
# (11, 10, 3)
# (11, 3)
# 129
# (2, 10, 3)
# (2, 3)
# 130
# (5, 10, 3)
# (5, 3)
# 131
# (3, 10, 3)
# (3, 3)
# 132
# (7, 10, 3)
# (7, 3)
# 133
# (40, 10, 3)
# (40, 3)
# 134
# (15, 10, 3)
# (15, 3)
# 135
# (0,)
# (0,)
# 136
# (13, 10, 3)
# (13, 3)
# 137
# (1, 10, 3)
# (1, 3)
# 138
# (4, 10, 3)
# (4, 3)
# 139
# (8, 10, 3)
# (8, 3)
# 140
# (0,)
# (0,)
# 141
# (35, 10, 3)
# (35, 3)
# 142
# (5, 10, 3)
# (5, 3)
# 143
# (16, 10, 3)
# (16, 3)
# 144
# (6, 10, 3)
# (6, 3)
# 145
# (0,)
# (0,)
# 146
# (164, 10, 3)
# (164, 3)
# 147
# (84, 10, 3)
# (84, 3)
# 148
# (8, 10, 3)
# (8, 3)
# 149
# (174, 10, 3)
# (174, 3)
# 150
# (386, 10, 3)
# (386, 3)
# 151
# (120, 10, 3)
# (120, 3)
# 152
# (1701, 10, 3)
# (1701, 3)
# 153
# (232, 10, 3)
# (232, 3)
# 154
# (145, 10, 3)
# (145, 3)
# 155
# (98, 10, 3)
# (98, 3)
# 156
# (622, 10, 3)
# (622, 3)
# 157
# (98, 10, 3)
# (98, 3)
# 158
# (58, 10, 3)
 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': 1.0},
#   {'relative_offset': 0.5, 'interval': -27.0, 'duration': 0.5},
#   {'relative_offset': 0.5, 'interval': 29.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.75, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 1.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': 1.0},
#   {'relative_offset': 0.5, 'interval': -27.0, 'duration': 0.5},
#   {'relative_offset': 0.5, 'interval': 29.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.75, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': 1.0},
#   {'relative_offset': 0.5, 'interval': -27.0, 'duration': 0.5},
#   {'relative_offset': 0.5, 'interval': 29.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.75, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': 0.0, 'duration': 0.0},
#   {'relative_offset': 0.25, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 2.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': -1.0, 'duration': Fraction(1, 3)},
#   {'relative_offset': 0.5, 'interval': 0.0, 'duration': Fraction(1, 3)}]]

# %%
# Save into a pickle file.
import pickle

pickle.dump( songs, open( "training_data_seqlength10.p", "wb" ) )

# %%
from keras.layers import Dense, Dropout, LSTM, Input
from keras import Model
from keras.metrics import SparseTopKCategoricalAccuracy

# %%
hid = 5
past_time_steps = 10
n_features = 3
future_time_steps = 1
inputs = Input(shape=(past_time_steps, n_features))
m = LSTM(hid, return_sequences=True)(inputs)
m = Dropout(0.5)(m)
m = LSTM(hid)(m)
m = Dropout(0.5)(m)

#outputA = Dense(future_time_steps, activation='linear')(m)
#outputB = Dense(future_time_steps, activation='linear')(m)
#outputC = Dense(future_time_steps, activation='linear')(m)

outputA = Dense(len(duration_to_number), activation='softmax')(m)
outputB = Dense(len(interval_to_number), activation='softmax')(m)
outputC = Dense(len(duration_to_number), activation='softmax')(m)

m = Model(inputs=[inputs], outputs=[outputA, outputB, outputC])
#m.compile(optimizer='adam', loss='mae')

m.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=[SparseTopKCategoricalAccuracy(k=3, name='sparse_top_k_categorical_accuracy')])


m.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 10, 3)        0
# __________________________________________________________________________________________________
# lstm_23 (LSTM)                  (None, 10, 5)        180         input_11[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 10, 5)        0           lstm_23[0][0]
# __________________________________________________________________________________________________
# lstm_24 (LSTM)                  (None, 5)            220         dropout_23[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 5)            0           lstm_24[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 121)          726         dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 199)          1194        dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 121)          726         dropout_24[0][0]
# ==================================================================================================
# Total params: 3,046
# Trainable params: 3,046
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# checkpoint
filepath="models_checkpoints/weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
callbacks_list = [checkpoint, early_stopping]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-ab6b696c9268> in <module>
#       2 filepath="models_checkpoints/weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
#       3 checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='min')
# ----> 4 early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
#       5 callbacks_list = [checkpoint, early_stopping]
#
# NameError: name 'EarlyStopping' is not defined

# %%
BATCH_SIZE = 64
EPOCHS = 50

# %%
y1 = y[:,0]
y2 = y[:,1]
y3 = y[:,2]

# %%
history = m.fit(X, [y1,y2,y3], validation_split = 0.1,  batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks_list)
# Out:
# Train on 61604 samples, validate on 6845 samples
# Epoch 1/50
# 61604/61604 [==============================] - 28s 458us/step - loss: 8.8256 - dense_29_loss: 2.3097 - dense_30_loss: 4.0251 - dense_31_loss: 2.4901 - dense_29_sparse_top_k_categorical_accuracy: 0.8300 - dense_30_sparse_top_k_categorical_accuracy: 0.3185 - dense_31_sparse_top_k_categorical_accuracy: 0.7287 - val_loss: 6.8884 - val_dense_29_loss: 1.4610 - val_dense_30_loss: 3.5472 - val_dense_31_loss: 1.8799 - val_dense_29_sparse_top_k_categorical_accuracy: 0.
- val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8355
#
# Epoch 00008: saving model to models_checkpoints/weights-improvement-08-6.45.hdf5
# Epoch 9/50
# 61604/61604 [==============================] - 26s 428us/step - loss: 6.2687 - dense_29_loss: 1.2724 - dense_30_loss: 3.5239 - dense_31_loss: 1.4722 - dense_29_sparse_top_k_categorical_accuracy: 0.8956 - dense_30_sparse_top_k_categorical_accuracy: 0.3689 - dense_31_sparse_top_k_categorical_accuracy: 0.8555 - val_loss: 6.4184 - val_dense_29_loss: 1.2809 - val_dense_30_loss: 3.5037 - val_dense_31_loss: 1.6335 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8777 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8294
#
# Epoch 00009: saving model to models_checkpoints/weights-improvement-09-6.42.hdf5
# Epoch 10/50
# 61604/61604 [==============================] - 27s 437us/step - loss: 6.2125 - dense_29_loss: 1.2468 - dense_30_loss: 3.5182 - dense_31_loss: 1.4475 - dense_29_sparse_top_k_categorical_accuracy: 0.9004 - dense_30_sparse_top_k_categorical_accuracy: 0.3688 - dense_31_sparse_top_k_categorical_accuracy: 0.8560 - val_loss: 6.3876 - val_dense_29_loss: 1.2799 - val_dense_30_loss: 3.4991 - val_dense_31_loss: 1.6081 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8795 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.83782478 - dense_30_loss: 3.5184 - dense_31_loss: 1.4465 - dense_29_sparse_top_k_categorical_accuracy: 0.9002 - dense_30_sparse_top_k_categorical_accuracy: 0.3687 - dense_31_sparse_to
#
# Epoch 00010: saving model to models_checkpoints/weights-improvement-10-6.39.hdf5
# Epoch 11/50
# 61604/61604 [==============================] - 27s 437us/step - loss: 6.1663 - dense_29_loss: 1.2264 - dense_30_loss: 3.5135 - dense_31_loss: 1.4265 - dense_29_sparse_top_k_categorical_accuracy: 0.9021 - dense_30_sparse_top_k_categorical_accuracy: 0.3691 - dense_31_sparse_top_k_categorical_accuracy: 0.8606 - val_loss: 6.3710 - val_dense_29_loss: 1.2783 - val_dense_30_loss: 3.4990 - val_dense_31_loss: 1.5932 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8805 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8583 - dense_30_loss: 3.5090 - dense_31_loss: 1.4287 - dense_29_sparse_top_k_categoric - ETA: 6s - loss: 6.1693 - dense_29_loss: 1.2255 - dense_30
#
# Epoch 00011: saving model to models_checkpoints/weights-improvement-11-6.37.hdf5
# Epoch 12/50
# 61604/61604 [==============================] - 25s 405us/step - loss: 6.1283 - dense_29_loss: 1.2147 - dense_30_loss: 3.5102 - dense_31_loss: 1.4032 - dense_29_sparse_top_k_categorical_accuracy: 0.9031 - dense_30_sparse_top_k_categorical_accuracy: 0.3690 - dense_31_sparse_top_k_categorical_accuracy: 0.8669 - val_loss: 6.2833 - val_dense_29_loss: 1.2556 - val_dense_30_loss: 3.4978 - val_dense_31_loss: 1.5293 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8839 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8697
#
# Epoch 00012: saving model to models_checkpoints/weights-improvement-12-6.28.hdf5
# Epoch 13/50
# 61604/61604 [==============================] - 25s 405us/step - loss: 6.0955 - dense_29_loss: 1.2132 - dense_30_loss: 3.5066 - dense_31_loss: 1.3760 - dense_29_sparse_top_k_categorical_accuracy: 0.9027 - dense_30_sparse_top_k_categorical_accuracy: 0.3692 - dense_31_sparse_top_k_categorical_accuracy: 0.8716 - val_loss: 6.2092 - val_dense_29_loss: 1.2490 - val_dense_30_loss: 3.4947 - val_dense_31_loss: 1.4649 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8831 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8760
#
# Epoch 00013: saving model to models_checkpoints/weights-improvement-13-6.21.hdf5
# Epoch 14/50
# 61604/61604 [==============================] - 25s 414us/step - loss: 6.0669 - dense_29_loss: 1.2076 - dense_30_loss: 3.5029 - dense_31_loss: 1.3565 - dense_29_sparse_top_k_categorical_accuracy: 0.9047 - dense_30_sparse_top_k_categorical_accuracy: 0.3690 - dense_31_sparse_top_k_categorical_accuracy: 0.8730 - val_loss: 6.2024 - val_dense_29_loss: 1.2721 - val_dense_30_loss: 3.4964 - val_dense_31_loss: 1.4334 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8815 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8782
#
# Epoch 00014: saving model to models_checkpoints/weights-improvement-14-6.20.hdf5
# Epoch 15/50
# 61604/61604 [==============================] - 28s 449us/step - loss: 6.0365 - dense_29_loss: 1.2037 - dense_30_loss: 3.5022 - dense_31_loss: 1.3307 - dense_29_sparse_top_k_categorical_accuracy: 0.9048 - dense_30_sparse_top_k_categorical_accuracy: 0.3696 - dense_31_sparse_top_k_categorical_accuracy: 0.8776 - val_loss: 6.1763 - val_dense_29_loss: 1.2675 - val_dense_30_loss: 3.4957 - val_dense_31_loss: 1.4125 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8836 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8773
#
# Epoch 00015: saving model to models_checkpoints/weights-improvement-15-6.18.hdf5
# Epoch 16/50
# 61604/61604 [==============================] - 26s 422us/step - loss: 6.0186 - dense_29_loss: 1.1999 - dense_30_loss: 3.4998 - dense_31_loss: 1.3189 - dense_29_sparse_top_k_categorical_accuracy: 0.9077 - dense_30_sparse_top_k_categorical_accuracy: 0.3694 - dense_31_sparse_top_k_categorical_accuracy: 0.8795 - val_loss: 6.1378 - val_dense_29_loss: 1.2413 - val_dense_30_loss: 3.4968 - val_dense_31_loss: 1.3991 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8871 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8720
#
# Epoch 00016: saving model to models_checkpoints/weights-improvement-16-6.14.hdf5
# Epoch 17/50
# 61604/61604 [==============================] - 26s 424us/step - loss: 5.9920 - dense_29_loss: 1.1910 - dense_30_loss: 3.4981 - dense_31_loss: 1.3029 - dense_29_sparse_top_k_categorical_accuracy: 0.9095 - dense_30_sparse_top_k_categorical_accuracy: 0.3691 - dense_31_sparse_top_k_categorical_accuracy: 0.8810 - val_loss: 6.1661 - val_dense_29_loss: 1.2555 - val_dense_30_loss: 3.4966 - val_dense_31_loss: 1.4135 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8856 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.87353.4971 - dense_31_loss: 1.3084 - dense_29_sparse_top_k_categorical_accuracy: 0.9075 - dense_30_sparse_top_k_categorical_accuracy: 0.3703 - dense_31_sparse_top_k_categorical_accuracy: - ETA: 15s - loss: 6.0073 - dense_29_loss: 1.2008 - dense_30_loss: 3.4982 - dense_3
#
# Epoch 00017: saving model to models_checkpoints/weights-improvement-17-6.17.hdf5
# Epoch 18/50
# 61604/61604 [==============================] - 26s 423us/step - loss: 5.9796 - dense_29_loss: 1.1861 - dense_30_loss: 3.4975 - dense_31_loss: 1.2961 - dense_29_sparse_top_k_categorical_accuracy: 0.9108 - dense_30_sparse_top_k_categorical_accuracy: 0.3695 - dense_31_sparse_top_k_categorical_accuracy: 0.8819 - val_loss: 6.1640 - val_dense_29_loss: 1.2577 - val_dense_30_loss: 3.4961 - val_dense_31_loss: 1.4097 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8885 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8742
#
# Epoch 00018: saving model to models_checkpoints/weights-improvement-18-6.16.hdf5
# Epoch 19/50
# 61604/61604 [==============================] - 27s 441us/step - loss: 5.9699 - dense_29_loss: 1.1837 - dense_30_loss: 3.4970 - dense_31_loss: 1.2890 - dense_29_sparse_top_k_categorical_accuracy: 0.9096 - dense_30_sparse_top_k_categorical_accuracy: 0.3694 - dense_31_sparse_top_k_categorical_accuracy: 0.8834 - val_loss: 6.2054 - val_dense_29_loss: 1.2577 - val_dense_30_loss: 3.4968 - val_dense_31_loss: 1.4502 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8893 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8732egorical_accuracy: 0.9098 - dense_30_sparse_top_k_categorical_accuracy: 0.3696 - dense_31_sparse_top_k_categorical_accuracy: 0. - ETA: 0s - loss: 5.9711 - dense_29_loss: 1.1837 - dense_30_loss: 3.4979 - dense_31_loss: 1.2896 - dense_29_sparse_top_k_categorical_accuracy: 0.9098 - dense_30_sparse_top_k_categorical_accuracy: 0.3695 - dense_31_sparse_to
#
# Epoch 00019: saving model to models_checkpoints/weights-improvement-19-6.21.hdf5
# Epoch 20/50
# 61604/61604 [==============================] - 27s 437us/step - loss: 5.9586 - dense_29_loss: 1.1788 - dense_30_loss: 3.4952 - dense_31_loss: 1.2846 - dense_29_sparse_top_k_categorical_accuracy: 0.9121 - dense_30_sparse_top_k_categorical_accuracy: 0.3696 - dense_31_sparse_top_k_categorical_accuracy: 0.8831 - val_loss: 6.2311 - val_dense_29_loss: 1.2806 - val_dense_30_loss: 3.4977 - val_dense_31_loss: 1.4522 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8720 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8767A: 3s - loss: 5.9646 - dense_29_loss: 1.1809 - dense_30_loss: 3.4962 - dense_31_loss: 1.2874 - dense_29_sparse_
#
# Epoch 00020: saving model to models_checkpoints/weights-improvement-20-6.23.hdf5
# Epoch 21/50
# 61604/61604 [==============================] - 27s 437us/step - loss: 5.9453 - dense_29_loss: 1.1761 - dense_30_loss: 3.4945 - dense_31_loss: 1.2748 - dense_29_sparse_top_k_categorical_accuracy: 0.9127 - dense_30_sparse_top_k_categorical_accuracy: 0.3696 - dense_31_sparse_top_k_categorical_accuracy: 0.8844 - val_loss: 6.2003 - val_dense_29_loss: 1.2632 - val_dense_30_loss: 3.4994 - val_dense_31_loss: 1.4371 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8748 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8738
#
# Epoch 00021: saving model to models_checkpoints/weights-improvement-21-6.20.hdf5
# Epoch 22/50
# 61604/61604 [==============================] - 27s 439us/step - loss: 5.9369 - dense_29_loss: 1.1750 - dense_30_loss: 3.4943 - dense_31_loss: 1.2677 - dense_29_sparse_top_k_categorical_accuracy: 0.9133 - dense_30_sparse_top_k_categorical_accuracy: 0.3698 - dense_31_sparse_top_k_categorical_accuracy: 0.8846 - val_loss: 6.2787 - val_dense_29_loss: 1.2808 - val_dense_30_loss: 3.5016 - val_dense_31_loss: 1.4956 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8647 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8618tegorical_accuracy: - ETA: 10s - loss: 5.9440 - dense_29_loss: 1.1745 - dense_30_loss: 3.4975 - dense_31_loss: 1.2719 - dense_29_sparse_top_k_categorical_accuracy: 0.91
#
# Epoch 00022: saving model to models_checkpoints/weights-improvement-22-6.28.hdf5
# Epoch 23/50
# 61604/61604 [==============================] - 27s 437us/step - loss: 5.9351 - dense_29_loss: 1.1732 - dense_30_loss: 3.4937 - dense_31_loss: 1.2682 - dense_29_sparse_top_k_categorical_accuracy: 0.9136 - dense_30_sparse_top_k_categorical_accuracy: 0.3695 - dense_31_sparse_top_k_categorical_accuracy: 0.8840 - val_loss: 6.2882 - val_dense_29_loss: 1.2750 - val_dense_30_loss: 3.5043 - val_dense_31_loss: 1.5082 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8650 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.86059_loss: 1.1719 - dense_30_loss: 3.4928 - dense_31_loss: 1.2670 - dense_29_sparse_top_k_categorical_accuracy: 0.9136 - dense_30_sparse_top_k_categorical_accuracy: 0
#
# Epoch 00023: saving model to models_checkpoints/weights-improvement-23-6.29.hdf5
# Epoch 24/50
# 61604/61604 [==============================] - 27s 438us/step - loss: 5.9381 - dense_29_loss: 1.1732 - dense_30_loss: 3.4935 - dense_31_loss: 1.2712 - dense_29_sparse_top_k_categorical_accuracy: 0.9129 - dense_30_sparse_top_k_categorical_accuracy: 0.3693 - dense_31_sparse_top_k_categorical_accuracy: 0.8830 - val_loss: 6.2870 - val_dense_29_loss: 1.2872 - val_dense_30_loss: 3.5034 - val_dense_31_loss: 1.4957 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8646 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8644
#
# Epoch 00024: saving model to models_checkpoints/weights-improvement-24-6.29.hdf5
# Epoch 25/50
# 61604/61604 [==============================] - 27s 441us/step - loss: 5.9311 - dense_29_loss: 1.1699 - dense_30_loss: 3.4933 - dense_31_loss: 1.2678 - dense_29_sparse_top_k_categorical_accuracy: 0.9135 - dense_30_sparse_top_k_categorical_accuracy: 0.3696 - dense_31_sparse_top_k_categorical_accuracy: 0.8820 - val_loss: 6.3453 - val_dense_29_loss: 1.2864 - val_dense_30_loss: 3.5056 - val_dense_31_loss: 1.5527 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8656 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8595
#
# Epoch 00025: saving model to models_checkpoints/weights-improvement-25-6.35.hdf5
# Epoch 26/50
# 61604/61604 [==============================] - 27s 439us/step - loss: 5.9248 - dense_29_loss: 1.1696 - dense_30_loss: 3.4928 - dense_31_loss: 1.2625 - dense_29_sparse_top_k_categorical_accuracy: 0.9124 - dense_30_sparse_top_k_categorical_accuracy: 0.3701 - dense_31_sparse_top_k_categorical_accuracy: 0.8835 - val_loss: 6.3772 - val_dense_29_loss: 1.3150 - val_dense_30_loss: 3.5072 - val_dense_31_loss: 1.5543 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8643 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8571
#
# Epoch 00026: saving model to models_checkpoints/weights-improvement-26-6.38.hdf5
# Epoch 27/50
# 61604/61604 [==============================] - 27s 442us/step - loss: 5.9268 - dense_29_loss: 1.1699 - dense_30_loss: 3.4923 - dense_31_loss: 1.2648 - dense_29_sparse_top_k_categorical_accuracy: 0.9140 - dense_30_sparse_top_k_categorical_accuracy: 0.3697 - dense_31_sparse_top_k_categorical_accuracy: 0.8826 - val_loss: 6.2819 - val_dense_29_loss: 1.2852 - val_dense_30_loss: 3.5046 - val_dense_31_loss: 1.4915 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8650 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8687
#
# Epoch 00027: saving model to models_checkpoints/weights-improvement-27-6.28.hdf5
# Epoch 28/50
# 61604/61604 [==============================] - 27s 440us/step - loss: 5.9131 - dense_29_loss: 1.1654 - dense_30_loss: 3.4931 - dense_31_loss: 1.2546 - dense_29_sparse_top_k_categorical_accuracy: 0.9138 - dense_30_sparse_top_k_categorical_accuracy: 0.3698 - dense_31_sparse_top_k_categorical_accuracy: 0.8847 - val_loss: 6.3008 - val_dense_29_loss: 1.2712 - val_dense_30_loss: 3.5059 - val_dense_31_loss: 1.5230 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8638 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8641
#
# Epoch 00028: saving model to models_checkpoints/weights-improvement-28-6.30.hdf5
# Epoch 29/50
# 61604/61604 [==============================] - 27s 438us/step - loss: 5.9204 - dense_29_loss: 1.1635 - dense_30_loss: 3.4917 - dense_31_loss: 1.2649 - dense_29_sparse_top_k_categorical_accuracy: 0.9146 - dense_30_sparse_top_k_categorical_accuracy: 0.3703 - dense_31_sparse_top_k_categorical_accuracy: 0.8815 - val_loss: 6.2544 - val_dense_29_loss: 1.2694 - val_dense_30_loss: 3.5052 - val_dense_31_loss: 1.4792 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8663 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8707257 - dense_29_loss: 1.1614 - dense_30_loss: 3.4990 - dense_31_loss: 1.2653 - dense_29_sparse_top_k_categorical_
#
# Epoch 00029: saving model to models_checkpoints/weights-improvement-29-6.25.hdf5
# Epoch 30/50
# 61604/61604 [==============================] - 27s 438us/step - loss: 5.9146 - dense_29_loss: 1.1640 - dense_30_loss: 3.4918 - dense_31_loss: 1.2586 - dense_29_sparse_top_k_categorical_accuracy: 0.9151 - dense_30_sparse_top_k_categorical_accuracy: 0.3691 - dense_31_sparse_top_k_categorical_accuracy: 0.8824 - val_loss: 6.2821 - val_dense_29_loss: 1.2702 - val_dense_30_loss: 3.5048 - val_dense_31_loss: 1.5064 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8656 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8697ategori
#
# Epoch 00030: saving model to models_checkpoints/weights-improvement-30-6.28.hdf5
# Epoch 31/50
# 61604/61604 [==============================] - 27s 436us/step - loss: 5.9171 - dense_29_loss: 1.1640 - dense_30_loss: 3.4918 - dense_31_loss: 1.2613 - dense_29_sparse_top_k_categorical_accuracy: 0.9151 - dense_30_sparse_top_k_categorical_accuracy: 0.3697 - dense_31_sparse_top_k_categorical_accuracy: 0.8819 - val_loss: 6.3527 - val_dense_29_loss: 1.2936 - val_dense_30_loss: 3.5071 - val_dense_31_loss: 1.5512 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8659 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8621
#
# Epoch 00031: saving model to models_checkpoints/weights-improvement-31-6.35.hdf5
# Epoch 32/50
# 61604/61604 [==============================] - 27s 446us/step - loss: 5.9131 - dense_29_loss: 1.1607 - dense_30_loss: 3.4920 - dense_31_loss: 1.2601 - dense_29_sparse_top_k_categorical_accuracy: 0.9152 - dense_30_sparse_top_k_categorical_accuracy: 0.3699 - dense_31_sparse_top_k_categorical_accuracy: 0.8805 - val_loss: 6.3302 - val_dense_29_loss: 1.2951 - val_dense_30_loss: 3.5088 - val_dense_31_loss: 1.5256 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8656 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.
#
# Epoch 00040: saving model to models_checkpoints/weights-improvement-40-6.23.hdf5
# Epoch 41/50
# 61604/61604 [==============================] - 25s 412us/step - loss: 5.8917 - dense_29_loss: 1.1407 - dense_30_loss: 3.4907 - dense_31_loss: 1.2607 - dense_29_sparse_top_k_categorical_accuracy: 0.9178 - dense_30_sparse_top_k_categorical_accuracy: 0.3700 - dense_31_sparse_top_k_categorical_accuracy: 0.8793 - val_loss: 6.3715 - val_dense_29_loss: 1.2893 - val_dense_30_loss: 3.5070 - val_dense_31_loss: 1.5745 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8767 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8412
#
# Epoch 00041: saving model to models_checkpoints/weights-improvement-41-6.37.hdf5
# Epoch 42/50
# 61604/61604 [==============================] - 25s 413us/step - loss: 5.8923 - dense_29_loss: 1.1431 - dense_30_loss: 3.4900 - dense_31_loss: 1.2590 - dense_29_sparse_top_k_categorical_accuracy: 0.9165 - dense_30_sparse_top_k_categorical_accuracy: 0.3705 - dense_31_sparse_top_k_categorical_accuracy: 0.8792 - val_loss: 6.2834 - val_dense_29_loss: 1.2607 - val_dense_30_loss: 3.5087 - val_dense_31_loss: 1.5134 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8893 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8504
#
# Epoch 00042: saving model to models_checkpoints/weights-improvement-42-6.28.hdf5
# Epoch 43/50
# 61604/61604 [==============================] - 26s 418us/step - loss: 5.8900 - dense_29_loss: 1.1386 - dense_30_loss: 3.4905 - dense_31_loss: 1.2608 - dense_29_sparse_top_k_categorical_accuracy: 0.9168 - dense_30_sparse_top_k_categorical_accuracy: 0.3706 - dense_31_sparse_top_k_categorical_accuracy: 0.8783 - val_loss: 6.2454 - val_dense_29_loss: 1.2345 - val_dense_30_loss: 3.5111 - val_dense_31_loss: 1.4992 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8897 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8580
#
# Epoch 00043: saving model to models_checkpoints/weights-improvement-43-6.25.hdf5
# Epoch 44/50
# 61604/61604 [==============================] - 27s 434us/step - loss: 5.8876 - dense_29_loss: 1.1389 - dense_30_loss: 3.4900 - dense_31_loss: 1.2585 - dense_29_sparse_top_k_categorical_accuracy: 0.9171 - dense_30_sparse_top_k_categorical_accuracy: 0.3701 - dense_31_sparse_top_k_categorical_accuracy: 0.8782 - val_loss: 6.2806 - val_dense_29_loss: 1.2459 - val_dense_30_loss: 3.5096 - val_dense_31_loss: 1.5244 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8891 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8539ense_29_loss: 1.1385 - dense_30_loss: 3.5050 - dense_31_loss: 1.2594 - dense_29_spars - ETA: 11s - loss: 5.8952 - dense_29_loss: 1.1361 - dense_30_loss: 3.4957 - dense_31_loss: 1.2634 - dense_29_sparse_top_k_categorical_accu
#
# Epoch 00044: saving model to models_checkpoints/weights-improvement-44-6.28.hdf5
# Epoch 45/50
# 61604/61604 [==============================] - 27s 441us/step - loss: 5.8869 - dense_29_loss: 1.1383 - dense_30_loss: 3.4896 - dense_31_loss: 1.2590 - dense_29_sparse_top_k_categorical_accuracy: 0.9179 - dense_30_sparse_top_k_categorical_accuracy: 0.3704 - dense_31_sparse_top_k_categorical_accuracy: 0.8778 - val_loss: 6.1871 - val_dense_29_loss: 1.2138 - val_dense_30_loss: 3.5107 - val_dense_31_loss: 1.4619 - val_dense_29_sparse_top_k_categorical_accuracy: 0.9040 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8590ense_30_sparse_top_k_categorical_ac - ETA: 11s - loss: 5.8942 - dense_29_loss: 1.1377 - dense_30_loss: 3.4925 - dense_31_loss: 1.2640 - dense_29_sparse_top_k
#
# Epoch 00045: saving model to models_checkpoints/weights-improvement-45-6.19.hdf5
# Epoch 46/50
# 61604/61604 [==============================] - 28s 447us/step - loss: 5.8843 - dense_29_loss: 1.1355 - dense_30_loss: 3.4891 - dense_31_loss: 1.2594 - dense_29_sparse_top_k_categorical_accuracy: 0.9184 - dense_30_sparse_top_k_categorical_accuracy: 0.3704 - dense_31_sparse_top_k_categorical_accuracy: 0.8780 - val_loss: 6.2936 - val_dense_29_loss: 1.2397 - val_dense_30_loss: 3.5114 - val_dense_31_loss: 1.5418 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8913 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8384
#
# Epoch 00046: saving model to models_checkpoints/weights-improvement-46-6.29.hdf5
# Epoch 47/50
# 61604/61604 [==============================] - 26s 424us/step - loss: 5.8849 - dense_29_loss: 1.1381 - dense_30_loss: 3.4889 - dense_31_loss: 1.2581 - dense_29_sparse_top_k_categorical_accuracy: 0.9172 - dense_30_sparse_top_k_categorical_accuracy: 0.3703 - dense_31_sparse_top_k_categorical_accuracy: 0.8773 - val_loss: 6.2579 - val_dense_29_loss: 1.2388 - val_dense_30_loss: 3.5098 - val_dense_31_loss: 1.5086 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8957 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8606
#
# Epoch 00047: saving model to models_checkpoints/weights-improvement-47-6.26.hdf5
# Epoch 48/50
# 61604/61604 [==============================] - 28s 453us/step - loss: 5.8843 - dense_29_loss: 1.1350 - dense_30_loss: 3.4896 - dense_31_loss: 1.2598 - dense_29_sparse_top_k_categorical_accuracy: 0.9167 - dense_30_sparse_top_k_categorical_accuracy: 0.3706 - dense_31_sparse_top_k_categorical_accuracy: 0.8781 - val_loss: 6.2888 - val_dense_29_loss: 1.2367 - val_dense_30_loss: 3.5087 - val_dense_31_loss: 1.5427 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8912 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.85273.4950 - dense_31_loss: 1.2409 - dense_29_sparse_top_k_categorical_accuracy: 0.9184 - dense_30_sparse_top_k_categoric - ETA: 16s - loss: 5.8793 - dense_29_loss: 1.1319 - dense_30_loss: 3.4953 - dense_31_loss: 1.2521 - ETA: 1s - loss: 5.8835 - dense_29_loss: 1.1352 - dense_30_loss: 3.4887 - dense_31_loss: 1.2595 - dense_29_sparse_top_k_categorical_accuracy: 0.9167 - dense_30_sparse_top_k_categorical_accuracy: 0.3711 - dense_31_sparse_top_k_categorical_accuracy: 0. - ETA: 1s - loss: 5.8845 - dense_29_loss: 1.1356 - dense_30_loss: 3.4894 - dense_31_loss: 1.2596 - dense_29_sparse_top_k_categorical_accuracy: 0.9166 - dense_30_sparse_top_k_categorical_accuracy: 0.3710 - dense_31_spars
#
# Epoch 00048: saving model to models_checkpoints/weights-improvement-48-6.29.hdf5
# Epoch 49/50
# 61604/61604 [==============================] - 27s 431us/step - loss: 5.8818 - dense_29_loss: 1.1352 - dense_30_loss: 3.4889 - dense_31_loss: 1.2577 - dense_29_sparse_top_k_categorical_accuracy: 0.9169 - dense_30_sparse_top_k_categorical_accuracy: 0.3702 - dense_31_sparse_top_k_categorical_accuracy: 0.8775 - val_loss: 6.2567 - val_dense_29_loss: 1.2330 - val_dense_30_loss: 3.5097 - val_dense_31_loss: 1.5133 - val_dense_29_sparse_top_k_categorical_accuracy: 0.8955 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8640 dense_29_loss: 1.1456 - dense_30_loss: 3.4766 -
#
# Epoch 00049: saving model to models_checkpoints/weights-improvement-49-6.26.hdf5
# Epoch 50/50
# 61604/61604 [==============================] - 27s 432us/step - loss: 5.8811 - dense_29_loss: 1.1329 - dense_30_loss: 3.4886 - dense_31_loss: 1.2593 - dense_29_sparse_top_k_categorical_accuracy: 0.9176 - dense_30_sparse_top_k_categorical_accuracy: 0.3707 - dense_31_sparse_top_k_categorical_accuracy: 0.8776 - val_loss: 6.2160 - val_dense_29_loss: 1.2194 - val_dense_30_loss: 3.5083 - val_dense_31_loss: 1.4877 - val_dense_29_sparse_top_k_categorical_accuracy: 0.9039 - val_dense_30_sparse_top_k_categorical_accuracy: 0.3860 - val_dense_31_sparse_top_k_categorical_accuracy: 0.8589
#
# Epoch 00050: saving model to models_checkpoints/weights-improvement-50-6.22.hdf5

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(m.history.history['loss'])
plt.plot(m.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from random import randint
def sample(preds):
    sorted_indexes = np.argsort(preds)[::-1]
    return sorted_indexes[randint(0,3)]

# %%
def sample_seq( seq, seq_length, model, number_to_note, output_seq_length ):
    if output_seq_length <= len(seq): raise Exception("output_seq_length must be higher than seq_length")
        
    output_seq = seq
    for i in range(output_seq_length - len(seq)):
        input_sequence = [seq[-seq_length:]]
        x = [pad_sequences(input_sequence, maxlen = seq_length, padding="pre")]
        prediction = model.predict(x)
        
        index1 = sample(prediction)
        
        index = sample(prediction[0])
        output_seq.append(index)
    #[number_to_note(number) for number in output_seq]
    return output_seq

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
def pad( input_seq, desired_length, fill_value):
    if len(input_seq) >= desired_length:
        return input_seq
    else: 
        [input_seq.insert(0, fill_value) for i in range(0, desired_length - len(input_seq))]
        return input_seq

# %%
def sample_seq( input_seq, length_expected_by_model, model, output_seq_length, padding_fill_value ):
    if output_seq_length <= len(input_seq): raise Exception("output_seq_length must be higher than seq_length")
        
    output_seq = input_seq
    for i in range(output_seq_length - len(input_seq)):
        input_sequence = input_seq[-length_expected_by_model:]
        x = [pad(input_sequence, length_expected_by_model, padding_fill_value)]
        #print(x)
        prediction = model.predict(np.array(x))
        #print(prediction[0][0])
        
        index1 = sample(prediction[0][0])
        index2 = sample(prediction[1][0])
        index3 = sample(prediction[2][0])
        #index = sample(prediction[0])
        output_seq.append([index1, index2, index3])
    return output_seq

# %%
sample_seq([[1,1,1]], 10, m, 5, [0,0,0])
# Out:
# [[1, 1, 1], [1, 102, 81], [0, 100, 81], [2, 100, 81], [3, 103, 81]]

# %%
generated_vector = sample_seq([[1,1,1]], 10, m, 50, [0,0,0])

# %%
generated_vector
# Out:
# [[1, 1, 1],
#  [1, 2, 0],
#  [3, 102, 0],
#  [0, 3, 2],
#  [3, 3, 1],
#  [2, 100, 1],
#  [3, 102, 0],
#  [2, 102, 1],
#  [3, 3, 2],
#  [2, 102, 1],
#  [3, 3, 1],
#  [3, 100, 2],
#  [1, 3, 1],
#  [1, 102, 1],
#  [2, 3, 0],
#  [2, 2, 4],
#  [3, 100, 0],
#  [1, 102, 1],
#  [1, 100, 2],
#  [2, 2, 1],
#  [1, 102, 2],
#  [2, 2, 81],
#  [1, 102, 2],
#  [4, 2, 2],
#  [3, 102, 1],
#  [4, 102, 81],
#  [3, 102, 1],
#  [3, 100, 1],
#  [1, 2, 81],
#  [2, 103, 2],
#  [1, 103, 4],
#  [2, 100, 4],
#  [2, 100, 2],
#  [2, 2, 81],
#  [4, 102, 4],
#  [1, 2, 4],
#  [1, 102, 4],
#  [4, 2, 1],
#  [2, 100, 81],
#  [4, 100, 2],
#  [1, 101, 81],
#  [2, 102, 81],
#  [1, 101, 1],
#  [3, 102, 0],
#  [0, 100, 1],
#  [3, 2, 1],
#  [4, 103, 81],
#  [3, 103, 81],
#  [2, 2, 4],
#  [1, 100, 4]]

# %%
generated_intervals = [{'relative_offset': generated_item[0], 'interval': generated_item[1], 'duration': generated_item[2]} for generated_item in generated_vector]

# %%
generated_intervals
# Out:
# [{'relative_offset': 1, 'interval': 1, 'duration': 1},
#  {'relative_offset': 1, 'interval': 2, 'duration': 0},
#  {'relative_offset': 3, 'interval': 102, 'duration': 0},
#  {'relative_offset': 0, 'interval': 3, 'duration': 2},
#  {'relative_offset': 3, 'interval': 3, 'duration': 1},
#  {'relative_offset': 2, 'interval': 100, 'duration': 1},
#  {'relative_offset': 3, 'interval': 102, 'duration': 0},
#  {'relative_offset': 2, 'interval': 102, 'duration': 1},
#  {'relative_offset': 3, 'interval': 3, 'duration': 2},
#  {'relative_offset': 2, 'interval': 102, 'duration': 1},
#  {'relative_offset': 3, 'interval': 3, 'duration': 1},
#  {'relative_offset': 3, 'interval': 100, 'duration': 2},
#  {'relative_offset': 1, 'interval': 3, 'duration': 1},
#  {'relative_offset': 1, 'interval': 102, 'duration': 1},
#  {'relative_offset': 2, 'interval': 3, 'duration': 0},
#  {'relative_offset': 2, 'interval': 2, 'duration': 4},
#  {'relative_offset': 3, 'interval': 100, 'duration': 0},
#  {'relative_offset': 1, 'interval': 102, 'duration': 1},
#  {'relative_offset': 1, 'interval': 100, 'duration': 2},
#  {'relative_offset': 2, 'interval': 2, 'duration': 1},
#  {'relative_offset': 1, 'interval': 102, 'duration': 2},
#  {'relative_offset': 2, 'interval': 2, 'duration': 81},
#  {'relative_offset': 1, 'interval': 102, 'duration': 2},
#  {'relative_offset': 4, 'interval': 2, 'duration': 2},
#  {'relative_offset': 3, 'interval': 102, 'duration': 1},
#  {'relative_offset': 4, 'interval': 102, 'duration': 81},
#  {'relative_offset': 3, 'interval': 102, 'duration': 1},
#  {'relative_offset': 3, 'interval': 100, 'duration': 1},
#  {'relative_offset': 1, 'interval': 2, 'duration': 81},
#  {'relative_offset': 2, 'interval': 103, 'duration': 2},
#  {'relative_offset': 1, 'interval': 103, 'duration': 4},
#  {'relative_offset': 2, 'interval': 100, 'duration': 4},
#  {'relative_offset': 2, 'interval': 100, 'duration': 2},
#  {'relative_offset': 2, 'interval': 2, 'duration': 81},
#  {'relative_offset': 4, 'interval': 102, 'duration': 4},
#  {'relative_offset': 1, 'interval': 2, 'duration': 4},
#  {'relative_offset': 1, 'interval': 102, 'duration': 4},
#  {'relative_offset': 4, 'interval': 2, 'duration': 1},
#  {'relative_offset': 2, 'interval': 100, 'duration': 81},
#  {'relative_offset': 4, 'interval': 100, 'duration': 2},
#  {'relative_offset': 1, 'interval': 101, 'duration': 81},
#  {'relative_offset': 2, 'interval': 102, 'duration': 81},
#  {'relative_offset': 1, 'interval': 101, 'duration': 1},
#  {'relative_offset': 3, 'interval': 102, 'duration': 0},
#  {'relative_offset': 0, 'interval': 100, 'duration': 1},
#  {'relative_offset': 3, 'interval': 2, 'duration': 1},
#  {'relative_offset': 4, 'interval': 103, 'duration': 81},
#  {'relative_offset': 3, 'interval': 103, 'duration': 81},
#  {'relative_offset': 2, 'interval': 2, 'duration': 4},
#  {'relative_offset': 1, 'interval': 100, 'duration': 4}]

# %%
from music21 import converter, corpus, instrument, midi, note, chord, pitch, stream, interval, duration

# %%
def from_array_of_intervals_to_pitches_with_time (root_pitch, intervals_with_time):
    elements = [{
            'absolute_offset': 0, 
            'pitch': root_pitch, 
            'duration': 1
        }]
    for interval in intervals_with_time:
        previousElement = elements[-1]
        resultElement = {
            'absolute_offset': float(previousElement['absolute_offset'] + interval['relative_offset']), 
            'pitch': float(previousElement['pitch'] + interval['interval']), 
            'duration': float(interval['duration']),
        }
        elements.append(resultElement)
    return elements

def from_pitches_with_time_to_midi (pitches_with_time, midi_path):
    print(pitches_with_time)
    streamResult = stream.Stream()
    for pitch_with_time in pitches_with_time:
        element = note.Note(pitch_with_time['pitch'])
        element._setOffset(pitch_with_time['absolute_offset'])
        d = duration.Duration()
        d.quarterLength = pitch_with_time['duration']
        element.duration = d
        streamResult.append(element)
            
    streamResult.write('midi', fp= midi_path)
    
def from_intervals_with_time_to_midi( root_pitch, intervals, midi_path):
    pitches_with_time = from_array_of_intervals_to_pitches_with_time(root_pitch, intervals)
    from_pitches_with_time_to_midi(pitches_with_time, midi_path)

# %%
#model_interval.load_weights('models_checkpoints/weights-improvement-10-2.87.hdf5')

# %%
from datetime import datetime

# %%
from_intervals_with_time_to_midi(1, generated_intervals, datetime.now().strftime("%Y%m%d_%H%M%S")+'_generated_record_intervals_tuning_with_time.mid')
# Out:
# [{'absolute_offset': 0, 'pitch': 1, 'duration': 1}, {'absolute_offset': 1.0, 'pitch': 2.0, 'duration': 1.0}, {'absolute_offset': 2.0, 'pitch': 4.0, 'duration': 0.0}, {'absolute_offset': 5.0, 'pitch': 106.0, 'duration': 0.0}, {'absolute_offset': 5.0, 'pitch': 109.0, 'duration': 2.0}, {'absolute_offset': 8.0, 'pitch': 112.0, 'duration': 1.0}, {'absolute_offset': 10.0, 'pitch': 212.0, 'duration': 1.0}, {'absolute_offset': 13.0, 'pitch': 314.0, 'duration': 0.0}, {'absolute_offset': 15.0, 'pitch': 416.0, '