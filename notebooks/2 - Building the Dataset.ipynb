# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanvr/Dathoven/blob/main/notebooks/2%20-%20Building%20the%20Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building the Dataset

# %% [markdown]
# ## Downloading the data

# %%
import requests

url = 'https://github.com/Juanvr/Dathoven/raw/main/compressed_data/data.zip'
r = requests.get(url, allow_redirects=True)

open('data.zip', 'wb').write(r.content);

# %%
import zipfile
with zipfile.ZipFile('data.zip', 'r') as zip_ref:
    zip_ref.extractall('data')

# %% [markdown]
# ## Importing dependencies

# %% [markdown]
# My first aproach is to use absolute tone of notes in order to generate the model.

# %%
import glob, os
import numpy as np
from matplotlib import pyplot as plt

# %%
! pip install --upgrade music21
# Out:
# Requirement already up-to-date: music21 in /usr/local/lib/python3.7/dist-packages (6.7.1)
# Requirement already satisfied, skipping upgrade: chardet in /usr/local/lib/python3.7/dist-packages (from music21) (3.0.4)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.7/dist-packages (from music21) (1.0.1)
# Requirement already satisfied, skipping upgrade: webcolors in /usr/local/lib/python3.7/dist-packages (from music21) (1.11.1)
# Requirement already satisfied, skipping upgrade: more-itertools in /usr/local/lib/python3.7/dist-packages (from music21) (8.8.0)

# %%
from music21 import converter, corpus, instrument, midi, note, chord, pitch, stream,interval

# %%
# !apt install fluidsynth
# !cp /usr/share/sounds/sf2/FluidR3_GM.sf2 ./font.sf2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fluidsynth is already the newest version (1.1.9-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
from IPython.display import Audio

# %% [markdown]
# ## Absolute approach

# %% [markdown]
# ### Getting the notes

# %% [markdown]
# #### From midi to notes and chords

# %% [markdown]
# We create a function that takes a midi file and returns all its notes and chords:

# %%
def get_stream_from_midi_without_drums(midi_path):
    mf = midi.MidiFile()
    mf.open(midi_path)
    mf.read()
    mf.close()
    
    for i in range(len(mf.tracks)):
        mf.tracks[i].events = [ev for ev in mf.tracks[i].events if ev.channel != 10]          

    return midi.translate.midiFileToStream(mf)

# %%
def stream_to_array_of_notes_strings (stream):
    result = []
    for element in stream.flat.notes:
        stringRepresentationOfElement = ''
        if isinstance(element, note.Note):
            stringRepresentationOfElement = element.nameWithOctave
        else: # it's a chord
            listOfNotesWithOctaves = [note.nameWithOctave for note in element.notes]
            stringRepresentationOfElement = ' '.join(listOfNotesWithOctaves)
        result.append(stringRepresentationOfElement)
    return result

# %%
def from_midi_to_array_of_notes (midi_path):
    return stream_to_array_of_notes_strings(get_stream_from_midi_without_drums(midi_path))

# %% [markdown]
# #### From notes and chords to midi

# %% [markdown]
# We create the function that takes an array of notes and chords and creates a midi file:

# %%
def from_array_of_elements_to_midi ( elements, midi_path ):
    streamResult = stream.Stream()
    for element in elements:
        if ' ' not in element:
            streamResult.append(note.Note(element))
        else:
            streamResult.append(chord.Chord(element))
    
    streamResult.write('midi', fp= midi_path)

# %%
from_array_of_elements_to_midi(["C4", "D4", "E4", "F4", "G4"], "test1.mid")

# %% [markdown]
# Let's hear it:

# %%
# !fluidsynth -ni font.sf2 test1.mid -F output.wav -r 4100
# Out:
# FluidSynth version 1.1.9
# Copyright (C) 2000-2018 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of E-mu Systems, Inc.
#
# Rendering audio to file 'output.wav'..

# %%
Audio('output.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Let's check that we can convert to our notation and back to midi:

# %%
url = 'https://github.com/Juanvr/Dathoven/raw/main/examples/silent_night_easy.mid'
r = requests.get(url, allow_redirects=True)

open('silent_night_easy.mid', 'wb').write(r.content);

# %%
stream_silent_night = get_stream_from_midi_without_drums("silent_night_easy.mid")

# %%
from_array_of_elements_to_midi(stream_to_array_of_notes_strings(stream_silent_night), "silent_night.mid")

# %%
# !fluidsynth -ni font.sf2 silent_night.mid -F output.wav -r 4100
# Out:
# FluidSynth version 1.1.9
# Copyright (C) 2000-2018 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of E-mu Systems, Inc.
#
# Rendering audio to file 'output.wav'..

# %%
Audio('output.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# As we can see, it's a version of silent night with all the notes of same duration and with the same offset between notes.

# %% [markdown]
# #### Iterating through song data folder

# %% [markdown]
# We create a function that goes through a folder of midi files reading its notes and chords:

# %%
def get_folder_songs(folder_path):
    songs = []
    for file in glob.glob(folder_path):
        songs.append(from_midi_to_array_of_notes(file))
    return songs

# %%
# Test
songs = get_folder_songs("data/*.mid")  # This step takes a while

# %%
songs[:1]
# Out:
# [['B4',
#   'B2',
#   'B2',
#   'F#5',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2',
#   'B4',
#   'B2',
#   'B2',
#   'B5',
#   'F#5',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2',
#   'B4',
#   'B2',
#   'B2',
#   'F#5',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2',
#   'E-5',
#   'B2',
#   'B2',
#   'F#5',
#   'B4',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2',
#   'B4',
#   'B2',
#   'B2',
#   'F#5',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2',
#   'B4',
#   'B2',
#   'B2',
#   'B5',
#   'F#5',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2',
#   'B4',
#   'B2',
#   'B2',
#   'F#5',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2',
#   'E-5',
#   'B2',
#   'B2',
#   'F#5',
#   'B4',
#   'B2',
#   'G#4',
#   'E2',
#   'E2',
#   'E2']]

# %% [markdown]
# Up to this point we have a list of all the songs. For each song we have a list of all the notes and chords that are part of the song.

# %% [markdown]
# We save the resulting list in a pickle for future use:

# %%
# Save into a pickle file.
import pickle

pickle.dump( songs, open( "songs_notes.p", "wb" ) )

# %% [markdown]
# ### Getting the notes with offset and duration

# %%
def stream_to_array_of_pitches_with_time (stream):
    result = []
    offsets = []
    for item in stream.flat.notes:
        element = []
        if isinstance(item, note.Note):
            element = item
        else: # it's a chord
            #pitch = [note.pitch.ps for note in element.notes][0]
            element = item.notes[0]
        
        resultElement = {
            'absolute_offset': element._getOffset(), 
            'pitch': element.pitch.ps, 
            'name': element.nameWithOctave,
            'duration': element.duration.quarterLength,
            #'element': element
        }
        #print(element.duration.quarterLength)
        
        if not resultElement['absolute_offset'] in offsets:  # only keep one note per time position
            if not resultElement['duration'] == 0:
                result.append(resultElement)
                offsets.append(resultElement['absolute_offset'])
    result.sort(key=lambda x: x['absolute_offset'])
    return result

# %%
def from_midi_to_array_of_pitches_with_time (midi_path):
    return stream_to_array_of_pitches_with_time(get_stream_from_midi_without_drums(midi_path))

# %%
def get_folder_songs_with_time(folder_path):
    songs = []
    for file in glob.glob(folder_path):
        songs.append(from_midi_to_array_of_pitches_with_time(file))
    return songs

# %%
songs_with_time = get_folder_songs_with_time("data/*.mid")  # This step takes a while

# %%
songs_with_time[:1]
# Out:
# [[{'absolute_offset': 0.0, 'duration': 3.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 1.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 3.0, 'duration': 1.0, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 4.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 5.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 7.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 8.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 9.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 10.0, 'duration': 0.5, 'name': 'B5', 'pitch': 83.0},
#   {'absolute_offset': 11.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 12.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 13.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 15.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 16.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 17.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 19.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 20.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 21.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 23.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 24.0, 'duration': 2.0, 'name': 'E-5', 'pitch': 75.0},
#   {'absolute_offset': 25.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 26.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 27.0, 'duration': 0.5, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 28.0, 'duration': 0.5, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 29.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 31.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 32.0, 'duration': 3.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 33.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 35.0, 'duration': 1.0, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 36.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 37.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 39.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 40.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 41.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 42.0, 'duration': 0.5, 'name': 'B5', 'pitch': 83.0},
#   {'absolute_offset': 43.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 44.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 45.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 47.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 48.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 49.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 51.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 52.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 53.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 55.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 56.0, 'duration': 2.0, 'name': 'E-5', 'pitch': 75.0},
#   {'absolute_offset': 57.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 58.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 59.0, 'duration': 0.5, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 60.0, 'duration': 0.5, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 61.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 63.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0}]]

# %% [markdown]
# For each song we have a list of all the notes that are part of the song, their time position and their duration. We save it in a pickle file.

# %%
pickle.dump( songs_with_time, open( "songs_notes_with_time.p", "wb" ) )

# %% [markdown]
# ### Getting the notes by track

# %%
def get_streams_from_midi_without_drums(midi_path):
    mf = midi.MidiFile()
    mf.open(midi_path)
    mf.read()
    mf.close()
    
    streams = []
    for track in mf.tracks:
        if (len(track.events) >0):
            track.events = [ev for ev in track.events if ev.channel != 10]
            if (len(track.events) > 0):
                streams.append(midi.translate.midiTrackToStream(track))          
    return streams

# %%
def from_midi_to_array_of_tracks(midi_path):
    streams = get_streams_from_midi_without_drums(midi_path)
    result = [stream_to_array_of_pitches_with_time(stream) for stream in streams if len(stream.flat.notes) > 0];
    return result

# %%
def get_folder_songs_with_tracks(folder_path):
    songs = []
    for file in glob.glob(folder_path):
        songs.append(from_midi_to_array_of_tracks(file))
    return songs

# %%
songs_with_tracks = get_folder_songs_with_tracks("data/*.mid")  # This step takes a while

# %%
songs_with_tracks[100:101]
# Out:
# [[[{'absolute_offset': 0.0, 'duration': 1.0, 'name': 'E3', 'pitch': 52.0}],
#   [{'absolute_offset': 0.0, 'duration': 1.0, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': Fraction(5, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0},
#    {'absolute_offset': 2.25, 'duration': 0.25, 'name': 'A3', 'pitch': 57.0},
#    {'absolute_offset': 3.0, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': Fraction(11, 3),
#     'duration': 0.25,
#     'name': 'A3',
#     'pitch': 57.0},
#    {'absolute_offset': 4.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 4.75, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 5.0, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 5.25, 'duration': 0.25, 'name': 'D4', 'pitch': 62.0},
#    {'absolute_offset': Fraction(16, 3),
#     'duration': 0.25,
#     'name': 'F#4',
#     'pitch': 66.0},
#    {'absolute_offset': 5.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': Fraction(17, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 5.75, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 6.0, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 6.25, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': Fraction(19, 3),
#     'duration': 0.25,
#     'name': 'E4',
#     'pitch': 64.0},
#    {'absolute_offset': 6.5, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': Fraction(20, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 6.75, 'duration': 0.25, 'name': 'D4', 'pitch': 62.0},
#    {'absolute_offset': 7.0, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': Fraction(23, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 7.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 8.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(25, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 8.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(26, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 8.75, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 9.0, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 9.25, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(28, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 9.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(29, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 9.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 10.0, 'duration': 0.25, 'name': 'A4', 'pitch': 69.0},
#    {'absolute_offset': 10.25, 'duration': 0.25, 'name': 'E5', 'pitch': 76.0},
#    {'absolute_offset': Fraction(31, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 10.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': Fraction(32, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 10.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 11.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(34, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 11.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(35, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 11.75, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 12.0, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 12.25, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(37, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 12.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(38, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 12.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 13.0, 'duration': 0.25, 'name': 'A4', 'pitch': 69.0},
#    {'absolute_offset': 13.25, 'duration': 0.25, 'name': 'E5', 'pitch': 76.0},
#    {'absolute_offset': Fraction(40, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 13.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': Fraction(50, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0},
#    {'absolute_offset': 17.25, 'duration': 0.25, 'name': 'A3', 'pitch': 57.0},
#    {'absolute_offset': 18.0, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 18.5, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': Fraction(56, 3),
#     'duration': 0.25,
#     'name': 'E4',
#     'pitch': 64.0},
#    {'absolute_offset': 19.25, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 19.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 19.75, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 20.0, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 20.25, 'duration': 0.25, 'name': 'D4', 'pitch': 62.0},
#    {'absolute_offset': Fraction(61, 3),
#     'duration': 0.25,
#     'name': 'F#4',
#     'pitch': 66.0},
#    {'absolute_offset': 20.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': Fraction(62, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 20.75, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 21.0, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 21.25, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': Fraction(64, 3),
#     'duration': 0.25,
#     'name': 'E4',
#     'pitch': 64.0},
#    {'absolute_offset': 21.5, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': Fraction(65, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 21.75, 'duration': 0.25, 'name': 'D4', 'pitch': 62.0},
#    {'absolute_offset': 22.0, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': Fraction(68, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 22.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 23.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(70, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 23.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(71, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 23.75, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 24.0, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 24.25, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(73, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 24.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(74, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 24.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 25.0, 'duration': 0.25, 'name': 'A4', 'pitch': 69.0},
#    {'absolute_offset': 25.25, 'duration': 0.25, 'name': 'E5', 'pitch': 76.0},
#    {'absolute_offset': Fraction(76, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 25.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': Fraction(77, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 25.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 26.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(79, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 26.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(80, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 26.75, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 27.0, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 27.25, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(82, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 27.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(83, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 27.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 28.0, 'duration': 0.25, 'name': 'A4', 'pitch': 69.0},
#    {'absolute_offset': 28.25, 'duration': 0.25, 'name': 'E5', 'pitch': 76.0},
#    {'absolute_offset': Fraction(85, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 28.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 31.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(95, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 31.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 32.0, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': 32.25, 'duration': 0.25, 'name': 'A4', 'pitch': 69.0},
#    {'absolute_offset': Fraction(97, 3),
#     'duration': 0.25,
#     'name': 'E4',
#     'pitch': 64.0},
#    {'absolute_offset': Fraction(98, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 32.75, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 33.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': 33.25, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(100, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 33.5, 'duration': 0.25, 'name': 'F#4', 'pitch': 66.0},
#    {'absolute_offset': Fraction(101, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 33.75, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': 34.0, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 34.25, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': Fraction(103, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 34.5, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': Fraction(104, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 34.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 35.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(106, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 35.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(107, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 35.75, 'duration': 0.25, 'name': 'E4', 'pitch': 64.0},
#    {'absolute_offset': 36.0, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 36.25, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(109, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 36.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(110, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 36.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 37.0, 'duration': 0.25, 'name': 'A4', 'pitch': 69.0},
#    {'absolute_offset': 37.25, 'duration': 0.25, 'name': 'E5', 'pitch': 76.0},
#    {'absolute_offset': Fraction(112, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 37.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': Fraction(113, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 37.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 38.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(115, 3),
#     'duration': 0.25,
#     'name': 'B4',
#     'pitch': 71.0},
#    {'absolute_offset': 38.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(116, 3),
#     'duration': 0.25,
#     'name': 'D5',
#     'pitch': 74.0},
#    {'absolute_offset': 38.75, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': 39.0, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': 39.25, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(118, 3),
#     'duration': 0.25,
#     'name': 'C5',
#     'pitch': 72.0},
#    {'absolute_offset': 39.5, 'duration': 0.25, 'name': 'B4', 'pitch': 71.0},
#    {'absolute_offset': Fraction(119, 3),
#     'duration': 0.25,
#     'name': 'G4',
#     'pitch': 67.0},
#    {'absolute_offset': 39.75, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0},
#    {'absolute_offset': 40.0, 'duration': 0.25, 'name': 'A4', 'pitch': 69.0},
#    {'absolute_offset': 40.25, 'duration': 0.25, 'name': 'E5', 'pitch': 76.0},
#    {'absolute_offset': Fraction(121, 3),
#     'duration': 0.25,
#     'name': 'A4',
#     'pitch': 69.0},
#    {'absolute_offset': 40.5, 'duration': 0.25, 'name': 'G4', 'pitch': 67.0}],
#   [{'absolute_offset': 4.5, 'duration': 0.25, 'name': 'E3', 'pitch': 52.0},
#    {'absolute_offset': Fraction(14, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0},
#    {'absolute_offset': 4.75, 'duration': 0.25, 'name': 'D3', 'pitch': 50.0},
#    {'absolute_offset': 5.0, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 5.25, 'duration': 0.25, 'name': 'G2', 'pitch': 43.0},
#    {'absolute_offset': Fraction(16, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0},
#    {'absolute_offset': Fraction(17, 3),
#     'duration': 0.25,
#     'name': 'A2',
#     'pitch': 45.0},
#    {'absolute_offset': 5.75, 'duration': 0.25, 'name': 'C4', 'pitch': 60.0},
#    {'absolute_offset': 6.0, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 6.25, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': Fraction(19, 3),
#     'duration': 0.25,
#     'name': 'D3',
#     'pitch': 50.0},
#    {'absolute_offset': 6.5, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 6.75, 'duration': 0.25, 'name': 'G2', 'pitch': 43.0},
#    {'absolute_offset': 7.0, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 7.25, 'duration': 0.25, 'name': 'C4', 'pitch': 60.0},
#    {'absolute_offset': Fraction(22, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0},
#    {'absolute_offset': 25.5, 'duration': 0.25, 'name': 'E3', 'pitch': 52.0},
#    {'absolute_offset': Fraction(77, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0},
#    {'absolute_offset': 25.75, 'duration': 0.25, 'name': 'D3', 'pitch': 50.0},
#    {'absolute_offset': 26.0, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 26.25, 'duration': 0.25, 'name': 'G2', 'pitch': 43.0},
#    {'absolute_offset': Fraction(79, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0},
#    {'absolute_offset': Fraction(80, 3),
#     'duration': 0.25,
#     'name': 'A2',
#     'pitch': 45.0},
#    {'absolute_offset': 26.75, 'duration': 0.25, 'name': 'C4', 'pitch': 60.0},
#    {'absolute_offset': 27.0, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 27.25, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': Fraction(82, 3),
#     'duration': 0.25,
#     'name': 'D3',
#     'pitch': 50.0},
#    {'absolute_offset': 27.5, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 27.75, 'duration': 0.25, 'name': 'G2', 'pitch': 43.0},
#    {'absolute_offset': 28.0, 'duration': 0.25, 'name': 'B3', 'pitch': 59.0},
#    {'absolute_offset': 28.25, 'duration': 0.25, 'name': 'C4', 'pitch': 60.0},
#    {'absolute_offset': Fraction(85, 3),
#     'duration': 0.25,
#     'name': 'B3',
#     'pitch': 59.0}],
#   [{'absolute_offset': 0.0, 'duration': 1.0, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 7.5,
#     'duration': Fraction(1, 3),
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 7.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 8.0, 'duration': 0.25, 'name': 'C2', 'pitch': 36.0},
#    {'absolute_offset': 8.25,
#     'duration': Fraction(1, 3),
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': Fraction(26, 3),
#     'duration': Fraction(1, 3),
#     'name': 'A1',
#     'pitch': 33.0},
#    {'absolute_offset': 9.0,
#     'duration': Fraction(1, 3),
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': Fraction(28, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 9.5, 'duration': 0.25, 'name': 'C2', 'pitch': 36.0},
#    {'absolute_offset': 9.75,
#     'duration': Fraction(1, 3),
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 10.0,
#     'duration': Fraction(1, 3),
#     'name': 'A1',
#     'pitch': 33.0},
#    {'absolute_offset': 10.5,
#     'duration': Fraction(1, 3),
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 10.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 11.0, 'duration': 0.25, 'name': 'C2', 'pitch': 36.0},
#    {'absolute_offset': 11.25,
#     'duration': Fraction(1, 3),
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': Fraction(35, 3),
#     'duration': Fraction(1, 3),
#     'name': 'A1',
#     'pitch': 33.0},
#    {'absolute_offset': 12.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': Fraction(37, 3),
#     'duration': 0.25,
#     'name': 'A1',
#     'pitch': 33.0},
#    {'absolute_offset': 12.5, 'duration': 0.25, 'name': 'C1', 'pitch': 24.0},
#    {'absolute_offset': 12.75,
#     'duration': Fraction(1, 3),
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 13.0,
#     'duration': Fraction(1, 3),
#     'name': 'A1',
#     'pitch': 33.0},
#    {'absolute_offset': 25.5, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 25.75, 'duration': 0.25, 'name': 'A1', 'pitch': 33.0},
#    {'absolute_offset': 26.0, 'duration': 0.25, 'name': 'C1', 'pitch': 24.0},
#    {'absolute_offset': 26.25,
#     'duration': Fraction(1, 3),
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': Fraction(80, 3),
#     'duration': Fraction(1, 3),
#     'name': 'A1',
#     'pitch': 33.0},
#    {'absolute_offset': 27.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': Fraction(82, 3),
#     'duration': 0.25,
#     'name': 'A1',
#     'pitch': 33.0},
#    {'absolute_offset': 27.5, 'duration': 0.25, 'name': 'C1', 'pitch': 24.0},
#    {'absolute_offset': 27.75,
#     'duration': Fraction(1, 3),
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 28.0,
#     'duration': Fraction(1, 3),
#     'name': 'A1',
#     'pitch': 33.0}],
#   [{'absolute_offset': 13.5, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(41, 3),
#     'duration': 0.25,
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 13.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 14.0, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 14.25, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': Fraction(43, 3),
#     'duration': 0.25,
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 14.5, 'duration': 0.25, 'name': 'B1', 'pitch': 35.0},
#    {'absolute_offset': Fraction(44, 3),
#     'duration': 0.25,
#     'name': 'F#1',
#     'pitch': 30.0},
#    {'absolute_offset': 14.75, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 15.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 15.25, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(46, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 15.5, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 15.75, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 16.0, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 16.25, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': Fraction(49, 3),
#     'duration': 0.25,
#     'name': 'E1',
#     'pitch': 28.0},
#    {'absolute_offset': 16.5, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(50, 3),
#     'duration': 0.25,
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 16.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 17.0, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 17.25, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': Fraction(52, 3),
#     'duration': 0.25,
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 17.5, 'duration': 0.25, 'name': 'B1', 'pitch': 35.0},
#    {'absolute_offset': Fraction(53, 3),
#     'duration': 0.25,
#     'name': 'F#1',
#     'pitch': 30.0},
#    {'absolute_offset': 17.75, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 18.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 18.25, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(55, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 18.5, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 18.75, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 19.0, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 19.25, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': Fraction(58, 3),
#     'duration': 0.25,
#     'name': 'E1',
#     'pitch': 28.0},
#    {'absolute_offset': 19.5, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(59, 3),
#     'duration': 0.25,
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 19.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 20.0, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 20.25, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': Fraction(61, 3),
#     'duration': 0.25,
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 20.5, 'duration': 0.25, 'name': 'B1', 'pitch': 35.0},
#    {'absolute_offset': Fraction(62, 3),
#     'duration': 0.25,
#     'name': 'F#1',
#     'pitch': 30.0},
#    {'absolute_offset': 20.75, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 21.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 21.25, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(64, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 21.5, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 21.75, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 22.0, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 22.25, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': Fraction(67, 3),
#     'duration': 0.25,
#     'name': 'E1',
#     'pitch': 28.0},
#    {'absolute_offset': 28.5, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(86, 3),
#     'duration': 0.25,
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 28.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 29.0, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 29.25, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': Fraction(88, 3),
#     'duration': 0.25,
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 29.5, 'duration': 0.25, 'name': 'B1', 'pitch': 35.0},
#    {'absolute_offset': Fraction(89, 3),
#     'duration': 0.25,
#     'name': 'F#1',
#     'pitch': 30.0},
#    {'absolute_offset': 29.75, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 30.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 30.25, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(91, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 30.5, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 30.75, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 31.0, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 31.25, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': Fraction(94, 3),
#     'duration': 0.25,
#     'name': 'E1',
#     'pitch': 28.0},
#    {'absolute_offset': 31.5, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(95, 3),
#     'duration': 0.25,
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 31.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 32.0, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 32.25, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': Fraction(97, 3),
#     'duration': 0.25,
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 32.5, 'duration': 0.25, 'name': 'B1', 'pitch': 35.0},
#    {'absolute_offset': Fraction(98, 3),
#     'duration': 0.25,
#     'name': 'F#1',
#     'pitch': 30.0},
#    {'absolute_offset': 32.75, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 33.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 33.25, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(100, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 33.5, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 33.75, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 34.0, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 34.25, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': Fraction(103, 3),
#     'duration': 0.25,
#     'name': 'E1',
#     'pitch': 28.0},
#    {'absolute_offset': 37.5, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(113, 3),
#     'duration': 0.25,
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 37.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 38.0, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 38.25, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': Fraction(115, 3),
#     'duration': 0.25,
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 38.5, 'duration': 0.25, 'name': 'B1', 'pitch': 35.0},
#    {'absolute_offset': Fraction(116, 3),
#     'duration': 0.25,
#     'name': 'F#1',
#     'pitch': 30.0},
#    {'absolute_offset': 38.75, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 39.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 39.25, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(118, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 39.5, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 39.75, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 40.0, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 40.25, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': Fraction(121, 3),
#     'duration': 0.25,
#     'name': 'E1',
#     'pitch': 28.0},
#    {'absolute_offset': 40.5, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(122, 3),
#     'duration': 0.25,
#     'name': 'E2',
#     'pitch': 40.0},
#    {'absolute_offset': 40.75, 'duration': 0.25, 'name': 'D2', 'pitch': 38.0},
#    {'absolute_offset': 41.0, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 41.25, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': Fraction(124, 3),
#     'duration': 0.25,
#     'name': 'G1',
#     'pitch': 31.0},
#    {'absolute_offset': 41.5, 'duration': 0.25, 'name': 'B1', 'pitch': 35.0},
#    {'absolute_offset': Fraction(125, 3),
#     'duration': 0.25,
#     'name': 'F#1',
#     'pitch': 30.0},
#    {'absolute_offset': 41.75, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': 42.0, 'duration': 0.25, 'name': 'E1', 'pitch': 28.0},
#    {'absolute_offset': 42.25, 'duration': 0.25, 'name': 'E2', 'pitch': 40.0},
#    {'absolute_offset': Fraction(127, 3),
#     'duration': 0.25,
#     'name': 'D2',
#     'pitch': 38.0},
#    {'absolute_offset': 42.5, 'duration': 0.25, 'name': 'A2', 'pitch': 45.0},
#    {'absolute_offset': 42.75, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 43.0, 'duration': 0.25, 'name': 'G1', 'pitch': 31.0},
#    {'absolute_offset': 43.25, 'duration': 0.25, 'name': 'F#1', 'pitch': 30.0},
#    {'absolute_offset': Fraction(130, 3),
#     'duration': 0.25,
#     'name': 'E1',
#     'pitch': 28.0}],
#   [{'absolute_offset': 0.0, 'duration': 1.0, 'name': 'E4', 'pitch': 64.0}]]]

# %% [markdown]
# We have a list of songs, for each song we have a list of tracks, for each track we have a list of notes with its offset and duration.

# %%
pickle.dump( songs_with_tracks, open( "songs_notes_with_tracks.p", "wb" ) )

# %% [markdown]
# ## Incremental approach

# %% [markdown]
# ### Getting the intervals

# %%
songs_with_time[:1]
# Out:
# [[{'absolute_offset': 0.0, 'duration': 3.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 1.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 3.0, 'duration': 1.0, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 4.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 5.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 7.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 8.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 9.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 10.0, 'duration': 0.5, 'name': 'B5', 'pitch': 83.0},
#   {'absolute_offset': 11.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 12.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 13.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 15.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 16.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 17.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 19.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 20.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 21.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 23.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 24.0, 'duration': 2.0, 'name': 'E-5', 'pitch': 75.0},
#   {'absolute_offset': 25.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 26.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 27.0, 'duration': 0.5, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 28.0, 'duration': 0.5, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 29.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 31.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 32.0, 'duration': 3.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 33.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 35.0, 'duration': 1.0, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 36.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 37.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 39.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 40.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 41.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 42.0, 'duration': 0.5, 'name': 'B5', 'pitch': 83.0},
#   {'absolute_offset': 43.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 44.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 45.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 47.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 48.0, 'duration': 2.0, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 49.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 51.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 52.0, 'duration': 2.0, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 53.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 55.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 56.0, 'duration': 2.0, 'name': 'E-5', 'pitch': 75.0},
#   {'absolute_offset': 57.5, 'duration': 0.5, 'name': 'B2', 'pitch': 47.0},
#   {'absolute_offset': 58.0, 'duration': 0.5, 'name': 'F#5', 'pitch': 78.0},
#   {'absolute_offset': 59.0, 'duration': 0.5, 'name': 'B4', 'pitch': 71.0},
#   {'absolute_offset': 60.0, 'duration': 0.5, 'name': 'G#4', 'pitch': 68.0},
#   {'absolute_offset': 61.5, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0},
#   {'absolute_offset': 63.0, 'duration': 0.5, 'name': 'E2', 'pitch': 40.0}]]

# %%
def from_pitches_to_intervals_with_time (array_of_pitches_with_time):
    intervals_with_time = []
    for i in range(1,len(array_of_pitches_with_time) - 1):

        first_element = array_of_pitches_with_time[i-1]
        second_element = array_of_pitches_with_time[i]
        resultElement = {
            'relative_offset': second_element['absolute_offset'] - first_element['absolute_offset'],
            'interval': second_element['pitch'] - first_element['pitch'],
            'duration': second_element['duration'], 
            'name': second_element['name'], 
            #'element': second_element['element']
        }
        intervals_with_time.append(resultElement)
    return intervals_with_time

# %%
songs_intervals = [from_pitches_to_intervals_with_time(song) for song in songs_with_time]

# %%
songs_intervals[:1]
# Out:
# [[{'duration': 0.5, 'interval': -24.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 1.0, 'interval': 31.0, 'name': 'F#5', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': -10.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 0.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': 31.0, 'name': 'B4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -24.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 36.0, 'name': 'B5', 'relative_offset': 0.5},
#   {'duration': 0.5, 'interval': -5.0, 'name': 'F#5', 'relative_offset': 1.0},
#   {'duration': 2.0, 'interval': -10.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 0.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': 31.0, 'name': 'B4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -24.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 31.0, 'name': 'F#5', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': -10.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 0.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': 35.0, 'name': 'E-5', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 31.0, 'name': 'F#5', 'relative_offset': 0.5},
#   {'duration': 0.5, 'interval': -7.0, 'name': 'B4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -3.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 0.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 3.0, 'interval': 31.0, 'name': 'B4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -24.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 1.0, 'interval': 31.0, 'name': 'F#5', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': -10.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 0.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': 31.0, 'name': 'B4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -24.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 36.0, 'name': 'B5', 'relative_offset': 0.5},
#   {'duration': 0.5, 'interval': -5.0, 'name': 'F#5', 'relative_offset': 1.0},
#   {'duration': 2.0, 'interval': -10.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 0.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': 31.0, 'name': 'B4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -24.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 31.0, 'name': 'F#5', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': -10.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 0.0, 'name': 'E2', 'relative_offset': 1.5},
#   {'duration': 2.0, 'interval': 35.0, 'name': 'E-5', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'B2', 'relative_offset': 1.5},
#   {'duration': 0.5, 'interval': 31.0, 'name': 'F#5', 'relative_offset': 0.5},
#   {'duration': 0.5, 'interval': -7.0, 'name': 'B4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -3.0, 'name': 'G#4', 'relative_offset': 1.0},
#   {'duration': 0.5, 'interval': -28.0, 'name': 'E2', 'relative_offset': 1.5}]]

# %% [markdown]
# We have a list of songs. For each song we have a list with the increments between its notes.

# %%
pickle.dump( songs_intervals, open( "songs_intervals.p", "wb" ) )

# %% [markdown]
# ### Getting the intervals by track

# %%
get_intervals_from_song = lambda song: [from_pitches_to_intervals_with_time(track) for track in song if len(track) > 2 ]

# %%
songs_intervals_by_track = [get_intervals_from_song(song) for song in songs_with_tracks]

# %%
songs_intervals_by_track[:1]
# Out:
# [[[{'duration': 0.25, 'interval': 7.0, 'name': 'F#5', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': -10.0,
#     'name': 'G#4',
#     'relative_offset': 0.08333333333333331},
#    {'duration': 0.25,
#     'interval': 3.0,
#     'name': 'B4',
#     'relative_offset': 0.4166666666666667},
#    {'duration': 0.25, 'interval': 12.0, 'name': 'B5', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': -12.0, 'name': 'B4', 'relative_offset': 0.5},
#    {'duration': 0.25, 'interval': 7.0, 'name': 'F#5', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': -3.0, 'name': 'E-5', 'relative_offset': 0.5},
#    {'duration': 0.25, 'interval': 3.0, 'name': 'F#5', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': -10.0,
#     'name': 'G#4',
#     'relative_offset': 0.16666666666666652},
#    {'duration': 0.25,
#     'interval': 3.0,
#     'name': 'B4',
#     'relative_offset': 0.3333333333333335},
#    {'duration': 0.25, 'interval': 7.0, 'name': 'F#5', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': -10.0,
#     'name': 'G#4',
#     'relative_offset': 0.08333333333333348},
#    {'duration': 0.25,
#     'interval': 3.0,
#     'name': 'B4',
#     'relative_offset': 0.4166666666666665},
#    {'duration': 0.25, 'interval': 12.0, 'name': 'B5', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': -12.0, 'name': 'B4', 'relative_offset': 0.5},
#    {'duration': 0.25, 'interval': 7.0, 'name': 'F#5', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': -3.0, 'name': 'E-5', 'relative_offset': 0.5},
#    {'duration': 0.25,
#     'interval': 3.0,
#     'name': 'F#5',
#     'relative_offset': 0.25}],
#   [{'duration': 0.25, 'interval': 0.0, 'name': 'B2', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': -7.0,
#     'name': 'E2',
#     'relative_offset': 0.08333333333333331},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.16666666666666669},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.16666666666666663},
#    {'duration': 0.25,
#     'interval': 7.0,
#     'name': 'B2',
#     'relative_offset': 0.08333333333333337},
#    {'duration': 0.25, 'interval': 0.0, 'name': 'B2', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': -7.0, 'name': 'E2', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.08333333333333326},
#    {'duration': 0.25,
#     'interval': 7.0,
#     'name': 'B2',
#     'relative_offset': 0.16666666666666674},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'B2',
#     'relative_offset': 0.16666666666666674},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'B2',
#     'relative_offset': 0.08333333333333326},
#    {'duration': 0.25, 'interval': -7.0, 'name': 'E2', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': 0.0, 'name': 'E2', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': 7.0,
#     'name': 'B2',
#     'relative_offset': 0.08333333333333348},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'B2',
#     'relative_offset': 0.16666666666666652},
#    {'duration': 0.25,
#     'interval': -7.0,
#     'name': 'E2',
#     'relative_offset': 0.16666666666666652},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.08333333333333348},
#    {'duration': 0.25, 'interval': 0.0, 'name': 'E2', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': 7.0, 'name': 'B2', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': -7.0,
#     'name': 'E2',
#     'relative_offset': 0.08333333333333348},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.16666666666666652},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.16666666666666652},
#    {'duration': 0.25,
#     'interval': 7.0,
#     'name': 'B2',
#     'relative_offset': 0.08333333333333348},
#    {'duration': 0.25, 'interval': 0.0, 'name': 'B2', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': -7.0, 'name': 'E2', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.08333333333333304},
#    {'duration': 0.25,
#     'interval': 7.0,
#     'name': 'B2',
#     'relative_offset': 0.16666666666666696},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'B2',
#     'relative_offset': 0.16666666666666696},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'B2',
#     'relative_offset': 0.08333333333333304},
#    {'duration': 0.25, 'interval': -7.0, 'name': 'E2', 'relative_offset': 0.25},
#    {'duration': 0.25, 'interval': 0.0, 'name': 'E2', 'relative_offset': 0.25},
#    {'duration': 0.25,
#     'interval': 7.0,
#     'name': 'B2',
#     'relative_offset': 0.08333333333333304},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'B2',
#     'relative_offset': 0.16666666666666696},
#    {'duration': 0.25,
#     'interval': -7.0,
#     'name': 'E2',
#     'relative_offset': 0.16666666666666696},
#    {'duration': 0.25,
#     'interval': 0.0,
#     'name': 'E2',
#     'relative_offset': 0.08333333333333304}]]]

# %% [markdown]
# We have a list of songs. For each song we have a list of tracks. For each track we have a list of intervals that tell us the variations between the notes on each track. We save it to a pickle:

# %%
pickle.dump( songs_intervals_by_track, open( "songs_intervals_by_track.p", "wb" ) )
